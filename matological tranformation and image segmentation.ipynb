# %% [markdown]
# # marfological tranformation nd image segmentation

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Dilation

# %%
img = cv.imread('C:/Users/admin/Downloads/go.jpg',0)
_,mask = cv.threshold(img,220,255,cv.THRESH_BINARY)
kernal = np.ones((5,5),np.uint8)
dilation = cv.dilate(mask,kernal,iterations=1)
erode = cv.erode(mask,kernal,iterations=1)
titles = ['image','mask','dilation','erode']
images = [img,mask,dilation,erode]
for i in range(len(images)):
    plt.subplot(2,2,i+1),plt.imshow(images[i])
